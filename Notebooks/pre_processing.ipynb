# %%
#import packages

import pandas as pd
import numpy as np

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# filter warning messages
import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# import data set and create a data frame
df_dataset = pd.read_csv('http://dl.dropboxusercontent.com/s/xn2a4kzf0zer0xu/acquisition_train.csv?dl=0')

# dataset shape
df_dataset.shape
df_dataset.head(2)
# Out:
# (45000, 43)
#                                     ids target_default  \
# 0  343b7e7b-2cf8-e508-b8fd-0a0285af30aa          False
# 1  bc2c7502-bbad-0f8c-39c3-94e881967124          False
#
#                     score_1                   score_2  score_3     score_4  \
# 0  1Rk8w4Ucd5yR3KcqZzLdow==  IOVu8au3ISbo6+zmfnYwMg==    350.0  101.800832
# 1  DGCQep2AE5QRkNCshIAlFQ==  SaamrHMo23l/3TwXOWgVzw==    370.0   97.062615
#
#     score_5     score_6  risk_rate  last_amount_borrowed  \
# 0  0.259555  108.427273       0.40              25033.92
# 1  0.942655   92.002546       0.24                   NaN
#
#    last_borrowed_in_months  credit_limit  \
# 0                     36.0           0.0
# 1                      NaN       39726.0
#
#                                               reason     income  \
# 0  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...   65014.12
# 1  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...  100018.91
#
#   facebook_profile                     state                       zip  \
# 0             True  sjJbkqJS7cXalHLBFA+EOQ==  Ernn+uVXCMq/6ARrBCcd+A==
# 1            False  xsd3ZdsI3356I3xMxZeiqQ==  rlWIXTBO+VOa34+SpGyhlQ==
#
#                     channel  \
# 0  NCqL3QBx0pscDnx3ixKwXg==
# 1  NCqL3QBx0pscDnx3ixKwXg==
#
#                                             job_name  \
# 0  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
# 1  mLVIVxoGY7TUDJ1FyFoSIZi1SFcaBmO01AydRchaEiGYtU...
#
#                  real_state  ok_since  n_bankruptcies  n_defaulted_loans  \
# 0  N5/CE7lSkAfB04hVFFwllw==       NaN             0.0                0.0
# 1  N5/CE7lSkAfB04hVFFwllw==      50.0             0.0                0.0
#
#    n_accounts  n_issues application_time_applied  application_time_in_funnel  \
# 0        18.0      18.0                 07:52:34                         444
# 1        14.0      14.0                 02:34:29                         346
#
#          email  external_data_provider_credit_checks_last_2_year  \
# 0  outlook.com                                               NaN
# 1    gmail.com                                               0.0
#
#    external_data_provider_credit_checks_last_month  \
# 0                                                2
# 1                                                1
#
#    external_data_provider_credit_checks_last_year  \
# 0                                             0.0
# 1                                             0.0
#
#    external_data_provider_email_seen_before external_data_provider_first_name  \
# 0                                      51.0                        leidelaura
# 1                                      17.0                          diocezio
#
#    external_data_provider_fraud_score  \
# 0                                 645
# 1                                 243
#
#                                      lat_lon marketing_channel  \
# 0   (-29.151545708122246, -51.1386461804385)      Invite-email
# 1  (-19.687710705798963, -47.94151536525154)  Radio-commercial
#
#   profile_phone_number  reported_income shipping_state  shipping_zip_code  \
# 0          514-9840782          57849.0          BR-MT              17528
# 1          251-3659293           4902.0          BR-RS              40933
#
#                     profile_tags  \
# 0        {'tags': ['n19', 'n8']}
# 1  {'tags': ['n6', 'n7', 'nim']}
#
#                                           user_agent target_fraud
# 0  Mozilla/5.0 (Linux; Android 6.0.1; SGP771 Buil...          NaN
# 1  Mozilla/5.0 (Linux; Android 5.0.2; SAMSUNG SM-...          NaN

# %%
# dataset summary
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 43 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   ids                                               45000 non-null  object
#  1   target_default                                    41741 non-null  object
#  2   score_1                                           44438 non-null  object
#  3   score_2                                           44438 non-null  object
#  4   score_3                                           44438 non-null  float64
#  5   score_4                                           45000 non-null  float64
#  6   score_5                                           45000 non-null  float64
#  7   score_6                                           45000 non-null  float64
#  8   risk_rate                                         44438 non-null  float64
#  9   last_amount_borrowed                              15044 non-null  float64
#  10  last_borrowed_in_months                           15044 non-null  float64
#  11  credit_limit                                      31200 non-null  float64
#  12  reason                                            44434 non-null  object
#  13  income                                            44438 non-null  float64
#  14  facebook_profile                                  40542 non-null  object
#  15  state                                             44438 non-null  object
#  16  zip                                               44438 non-null  object
#  17  channel                                           44438 non-null  object
#  18  job_name                                          41664 non-null  object
#  19  real_state                                        44438 non-null  object
#  20  ok_since                                          18455 non-null  float64
#  21  n_bankruptcies                                    44303 non-null  float64
#  22  n_defaulted_loans                                 44426 non-null  float64
#  23  n_accounts                                        44438 non-null  float64
#  24  n_issues                                          33456 non-null  float64
#  25  application_time_applied                          45000 non-null  object
#  26  application_time_in_funnel                        45000 non-null  int64
#  27  email                                             45000 non-null  object
#  28  external_data_provider_credit_checks_last_2_year  22372 non-null  float64
#  29  external_data_provider_credit_checks_last_month   45000 non-null  int64
#  30  external_data_provider_credit_checks_last_year    29876 non-null  float64
#  31  external_data_provider_email_seen_before          42767 non-null  float64
#  32  external_data_provider_first_name                 45000 non-null  object
#  33  external_data_provider_fraud_score                45000 non-null  int64
#  34  lat_lon                                           43637 non-null  object
#  35  marketing_channel                                 41422 non-null  object
#  36  profile_phone_number                              45000 non-null  object
#  37  reported_income                                   45000 non-null  float64
#  38  shipping_state                                    45000 non-null  object
#  39  shipping_zip_code                                 45000 non-null  int64
#  40  profile_tags                                      45000 non-null  object
#  41  user_agent                                        44278 non-null  object
#  42  target_fraud                                      1522 non-null   object
# dtypes: float64(18), int64(4), object(21)
# memory usage: 14.8+ MB

# %%
# percentage of missing values per feature
(df_dataset.isnull().sum() * 100 / df_dataset.shape[0]).round(2).sort_values(ascending=False)
# Out:
# target_fraud                                        96.62
# last_borrowed_in_months                             66.57
# last_amount_borrowed                                66.57
# ok_since                                            58.99
# external_data_provider_credit_checks_last_2_year    50.28
# external_data_provider_credit_checks_last_year      33.61
# credit_limit                                        30.67
# n_issues                                            25.65
# facebook_profile                                     9.91
# marketing_channel                                    7.95
# job_name                                             7.41
# target_default                                       7.24
# external_data_provider_email_seen_before             4.96
# lat_lon                                              3.03
# user_agent                                           1.60
# n_bankruptcies                                       1.55
# n_defaulted_loans                                    1.28
# reason                                               1.26
# risk_rate                                            1.25
# income                                               1.25
# state                                                1.25
# n_accounts                                           1.25
# real_state                                           1.25
# score_3                                              1.25
# score_2                                              1.25
# score_1                                              1.25
# channel                                              1.25
# zip                                                  1.25
# score_5                                              0.00
# score_4                                              0.00
# ids                                                  0.00
# score_6                                              0.00
# application_time_applied                             0.00
# application_time_in_funnel                           0.00
# external_data_provider_credit_checks_last_month      0.00
# external_data_provider_fraud_score                   0.00
# external_data_provider_first_name                    0.00
# email                                                0.00
# profile_phone_number                                 0.00
# shipping_state                                       0.00
# reported_income                                      0.00
# profile_tags                                         0.00
# shipping_zip_code                                    0.00
# dtype: float64

# %%
## target_default is the DV -> we need only the data which have DV for training and testing
df_dataset.dropna(subset=['target_default'], inplace=True)
df_dataset.shape
# Out:
# (41741, 43)

# %%
# drop the column "target_fraud" as the missing % is very high
df_dataset.drop('target_fraud', axis=1, inplace=True)
df_dataset.shape
# Out:
# (41741, 42)

# %%
#no. of unique values of the features
df_dataset.nunique().sort_values()
# Out:
# external_data_provider_credit_checks_last_2_year        1
# channel                                                 1
# target_default                                          2
# last_borrowed_in_months                                 2
# facebook_profile                                        2
# external_data_provider_credit_checks_last_year          2
# external_data_provider_credit_checks_last_month         4
# n_defaulted_loans                                       5
# real_state                                              5
# email                                                   6
# n_bankruptcies                                          6
# score_1                                                 7
# marketing_channel                                       9
# shipping_state                                         25
# score_2                                                35
# n_issues                                               44
# n_accounts                                             44
# state                                                  50
# external_data_provider_email_seen_before               62
# risk_rate                                              81
# score_3                                                87
# ok_since                                              100
# user_agent                                            297
# application_time_in_funnel                            501
# zip                                                   823
# external_data_provider_fraud_score                   1001
# last_amount_borrowed                                13480
# reason                                              14260
# credit_limit                                        19336
# lat_lon                                             21596
# profile_tags                                        24458
# shipping_zip_code                                   26996
# job_name                                            30543
# external_data_provider_first_name                   31183
# application_time_applied                            33560
# reported_income                                     37368
# income                                              38849
# score_5                                             41741
# score_4                                             41741
# ids                                                 41741
# score_6                                             41741
# profile_phone_number                                41741
# dtype: int64

# %%
df_dataset['channel'].isnull().sum()/df_dataset.shape[0]*100
# Out:
# np.float64(0.0)

# %%
# drop the columns "channel" (0% missing and all the values are the same)
df_dataset.drop(labels=['channel'], axis=1, inplace=True)

# %%
df_dataset['external_data_provider_credit_checks_last_2_year'].isnull().sum()/df_dataset.shape[0]*100
# Out:
# np.float64(50.382118300951106)

# %%
# drop the columns "external_data_provider_credit_checks_last_2_year" (50% missing and remaining all are zero(no checks) -> meaning no data or no checks)
df_dataset.drop(labels=['external_data_provider_credit_checks_last_2_year'], axis=1, inplace=True)

# %%
# Columns that are not useful for training the data

df_dataset.drop(labels=['email', 'reason', 'zip', 'job_name', 'external_data_provider_first_name', 'lat_lon',
                       'shipping_zip_code', 'user_agent', 'profile_tags', 'marketing_channel',
                       'profile_phone_number', 'application_time_applied', 'ids'], axis=1, inplace=True)

# %%
# show descriptive statistics
df_dataset.describe()
# Out:
#             score_3       score_4       score_5       score_6     risk_rate  \
# count  41741.000000  41741.000000  41741.000000  41741.000000  41741.000000
# mean     346.459836    100.006820      0.499416     99.919399      0.294451
# std      110.102271      3.183821      0.288085     10.022703      0.101561
# min        0.000000     86.191572      0.000035     60.663039      0.000000
# 25%      270.000000     97.862546      0.251595     93.182517      0.220000
# 50%      340.000000    100.017950      0.500174     99.977774      0.290000
# 75%      420.000000    102.143100      0.747630    106.630991      0.360000
# max      990.000000    113.978234      0.999973    142.192400      0.900000
#
#        last_amount_borrowed  last_borrowed_in_months   credit_limit  \
# count          14133.000000             14133.000000   28632.000000
# mean           13328.104095                40.588410   33877.220453
# std             7918.698433                 9.437936   36141.985884
# min             1005.180000                36.000000       0.000000
# 25%             7210.280000                36.000000    9975.000000
# 50%            12011.050000                36.000000   25213.000000
# 75%            18030.160000                36.000000   46492.500000
# max            35059.600000                60.000000  448269.000000
#
#              income      ok_since  n_bankruptcies  n_defaulted_loans  \
# count  4.174100e+04  17276.000000    41606.000000       41729.000000
# mean   7.108012e+04     35.192174        0.076696           0.004625
# std    5.225978e+04     21.629577        0.274820           0.080157
# min    4.821180e+03      0.000000        0.000000           0.000000
# 25%    4.401958e+04     17.000000        0.000000           0.000000
# 50%    6.004409e+04     32.000000        0.000000           0.000000
# 75%    8.503289e+04     50.000000        0.000000           0.000000
# max    5.000028e+06    141.000000        5.000000           5.000000
#
#          n_accounts      n_issues  application_time_in_funnel  \
# count  41741.000000  30818.000000                41741.000000
# mean      10.639108     11.023882                  247.748545
# std        4.588175      4.596036                  146.326172
# min        0.000000      0.000000                    0.000000
# 25%        7.000000      8.000000                  120.000000
# 50%       10.000000     10.000000                  248.000000
# 75%       13.000000     14.000000                  375.000000
# max       49.000000     49.000000                  500.000000
#
#        external_data_provider_credit_checks_last_month  \
# count                                     41741.000000
# mean                                          1.504396
# std                                           1.114207
# min                                           0.000000
# 25%                                           1.000000
# 50%                                           2.000000
# 75%                                           2.000000
# max                                           3.000000
#
#        external_data_provider_credit_checks_last_year  \
# count                                    27720.000000
# mean                                         0.504185
# std                                          0.499992
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          1.000000
# 75%                                          1.000000
# max                                          1.000000
#
#        external_data_provider_email_seen_before  \
# count                              39656.000000
# mean                                  12.731188
# std                                  125.711218
# min                                 -999.000000
# 25%                                   11.000000
# 50%                                   27.000000
# 75%                                   43.000000
# max                                   59.000000
#
#        external_data_provider_fraud_score  reported_income
# count                        41741.000000          41741.0
# mean                           500.491771              inf
# std                            287.993121              NaN
# min                              0.000000            403.0
# 25%                            252.000000          50910.0
# 50%                            502.000000         101623.0
# 75%                            747.000000         151248.0
# max                           1000.000000              inf

# %%
# count of "inf" values in "reported_income"
np.isinf(df_dataset['reported_income']).sum()
# Out:
# np.int64(66)

# %%
# count of values = -999 (special values) in "external_data_provider_email_seen_before"
df_dataset.loc[df_dataset['external_data_provider_email_seen_before'] == -999, 'external_data_provider_email_seen_before'].value_counts()
# Out:
# external_data_provider_email_seen_before
# -999.0    591
# Name: count, dtype: int64

# %%
# Lets replace "inf" and "-999" values with "nan"
df_dataset['reported_income'] = df_dataset['reported_income'].replace(np.inf, np.nan)
df_dataset.loc[df_dataset['external_data_provider_email_seen_before'] == -999, 'external_data_provider_email_seen_before'] = np.nan

# %%
# dataset summary
df_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 41741 entries, 0 to 44999
# Data columns (total 27 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   target_default                                   41741 non-null  object
#  1   score_1                                          41741 non-null  object
#  2   score_2                                          41741 non-null  object
#  3   score_3                                          41741 non-null  float64
#  4   score_4                                          41741 non-null  float64
#  5   score_5                                          41741 non-null  float64
#  6   score_6                                          41741 non-null  float64
#  7   risk_rate                                        41741 non-null  float64
#  8   last_amount_borrowed                             14133 non-null  float64
#  9   last_borrowed_in_months                          14133 non-null  float64
#  10  credit_limit                                     28632 non-null  float64
#  11  income                                           41741 non-null  float64
#  12  facebook_profile                                 37588 non-null  object
#  13  state                                            41741 non-null  object
#  14  real_state                                       41741 non-null  object
#  15  ok_since                                         17276 non-null  float64
#  16  n_bankruptcies                                   41606 non-null  float64
#  17  n_defaulted_loans                                41729 non-null  float64
#  18  n_accounts                                       41741 non-null  float64
#  19  n_issues                                         30818 non-null  float64
#  20  application_time_in_funnel                       41741 non-null  int64
#  21  external_data_provider_credit_checks_last_month  41741 non-null  int64
#  22  external_data_provider_credit_checks_last_year   27720 non-null  float64
#  23  external_data_provider_email_seen_before         39065 non-null  float64
#  24  external_data_provider_fraud_score               41741 non-null  int64
#  25  reported_income                                  41675 non-null  float64
#  26  shipping_state                                   41741 non-null  object
# dtypes: float64(17), int64(3), object(7)
# memory usage: 8.9+ MB

# %%
df_dataset.head(2)
# Out:
#   target_default                   score_1                   score_2  score_3  \
# 0          False  1Rk8w4Ucd5yR3KcqZzLdow==  IOVu8au3ISbo6+zmfnYwMg==    350.0
# 1          False  DGCQep2AE5QRkNCshIAlFQ==  SaamrHMo23l/3TwXOWgVzw==    370.0
#
#       score_4   score_5     score_6  risk_rate  last_amount_borrowed  \
# 0  101.800832  0.259555  108.427273       0.40              25033.92
# 1   97.062615  0.942655   92.002546       0.24                   NaN
#
#    last_borrowed_in_months  credit_limit     income facebook_profile  \
# 0                     36.0           0.0   65014.12             True
# 1                      NaN       39726.0  100018.91            False
#
#                       state                real_state  ok_since  \
# 0  sjJbkqJS7cXalHLBFA+EOQ==  N5/CE7lSkAfB04hVFFwllw==       NaN
# 1  xsd3ZdsI3356I3xMxZeiqQ==  N5/CE7lSkAfB04hVFFwllw==      50.0
#
#    n_bankruptcies  n_defaulted_loans  n_accounts  n_issues  \
# 0             0.0                0.0        18.0      18.0
# 1             0.0                0.0        14.0      14.0
#
#    application_time_in_funnel  \
# 0                         444
# 1                         346
#
#    external_data_provider_credit_checks_last_month  \
# 0                                                2
# 1                                                1
#
#    external_data_provider_credit_checks_last_year  \
# 0                                             0.0
# 1                                             0.0
#
#    external_data_provider_email_seen_before  \
# 0                                      51.0
# 1                                      17.0
#
#    external_data_provider_fraud_score  reported_income shipping_state
# 0                                 645          57849.0          BR-MT
# 1                                 243           4902.0          BR-RS

# %%
# dataset containing numerical features
df_dataset_numerical = df_dataset.select_dtypes(
    include=['int64', 'float64']
)
df_dataset_numerical.shape
# Out:
# (41741, 20)

# %%
df_dataset_num = df_dataset.select_dtypes(exclude='object').columns
df_dataset_cat = df_dataset.select_dtypes(include='object').columns

# fill missing values for "last_amount_borrowed", "last_borrowed_in_months" and "n_issues" as 0  bcz not every client would have values assigned to these variables.
df_dataset['last_amount_borrowed'].fillna(value=0, inplace=True)
df_dataset['last_borrowed_in_months'].fillna(value=0, inplace=True)
df_dataset['n_issues'].fillna(value=0, inplace=True)

# %%
# fill missing values for numerical variables with median
imputer = SimpleImputer(missing_values=np.nan, strategy='median')
imputer = imputer.fit(df_dataset.loc[:, df_dataset_num])
df_dataset.loc[:, df_dataset_num] = imputer.transform(df_dataset.loc[:, df_dataset_num])

# %%
# fill missing values for categorical variables with most recuuring
imputer = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
imputer = imputer.fit(df_dataset.loc[:, df_dataset_cat])
df_dataset.loc[:, df_dataset_cat] = imputer.transform(df_dataset.loc[:, df_dataset_cat])

# %%
df_dataset.isnull().sum()
# Out:
# target_default                                     0
# score_1                                            0
# score_2                                            0
# score_3                                            0
# score_4                                            0
# score_5                                            0
# score_6                                            0
# risk_rate                                          0
# last_amount_borrowed                               0
# last_borrowed_in_months                            0
# credit_limit                                       0
# income                                             0
# facebook_profile                                   0
# state                                              0
# real_state                                         0
# ok_since                                           0
# n_bankruptcies                                     0
# n_defaulted_loans                                  0
# n_accounts                                         0
# n_issues                                           0
# application_time_in_funnel                         0
# external_data_provider_credit_checks_last_month    0
# external_data_provider_credit_checks_last_year     0
# external_data_provider_email_seen_before           0
# external_data_provider_fraud_score                 0
# reported_income                                    0
# shipping_state                                     0
# dtype: int64

# %%
## Now converting cat values to numericals
df_dataset.shape

bin_var = df_dataset.nunique()[df_dataset.nunique() == 2].keys().tolist()
num_var = [col for col in  df_dataset.select_dtypes(['int', 'float']).columns.tolist() if col not in bin_var]
cat_var = [col for col in  df_dataset.select_dtypes(['object']).columns.tolist() if col not in bin_var]

bin_var
num_var
cat_var
# Out:
# (41741, 27)
# ['target_default',
#  'facebook_profile',
#  'external_data_provider_credit_checks_last_year']
# ['score_3',
#  'score_4',
#  'score_5',
#  'score_6',
#  'risk_rate',
#  'last_amount_borrowed',
#  'last_borrowed_in_months',
#  'credit_limit',
#  'income',
#  'ok_since',
#  'n_bankruptcies',
#  'n_defaulted_loans',
#  'n_accounts',
#  'n_issues',
#  'application_time_in_funnel',
#  'external_data_provider_credit_checks_last_month',
#  'external_data_provider_email_seen_before',
#  'external_data_provider_fraud_score',
#  'reported_income']
# ['score_1', 'score_2', 'state', 'real_state', 'shipping_state']

# %%
df_dataset_encoded = df_dataset.copy()

# label encoding for the binary variables
label_encoder = LabelEncoder()
for col in bin_var:
  df_dataset_encoded[col] = label_encoder.fit_transform(df_dataset_encoded[col])

# encoding with get_dummies for the categorical variables
df_dataset_encoded = pd.get_dummies(df_dataset_encoded, columns=cat_var)
df_dataset_encoded.shape
df_dataset_encoded.head()
# Out:
# (41741, 144)
#    target_default  score_3     score_4   score_5     score_6  risk_rate  \
# 0               0    350.0  101.800832  0.259555  108.427273       0.40
# 1               0    370.0   97.062615  0.942655   92.002546       0.24
# 2               1    360.0  100.027073  0.351918  112.892453       0.29
# 3               0    510.0  101.599485  0.987673   94.902491       0.32
# 4               0    500.0   98.474289  0.532539  118.126207       0.18
#
#    last_amount_borrowed  last_borrowed_in_months  credit_limit     income  \
# 0              25033.92                     36.0           0.0   65014.12
# 1                  0.00                      0.0       39726.0  100018.91
# 2               7207.92                     36.0       25213.0   65023.65
# 3                  0.00                      0.0       54591.0   68830.01
# 4                  0.00                      0.0       25213.0   60011.29
#
#    facebook_profile  ok_since  n_bankruptcies  n_defaulted_loans  n_accounts  \
# 0                 1      32.0             0.0                0.0        18.0
# 1                 0      50.0             0.0                0.0        14.0
# 2                 0      32.0             0.0                0.0        10.0
# 3                 0      32.0             1.0                0.0        19.0
# 4                 1      32.0             0.0                0.0        11.0
#
#    n_issues  application_time_in_funnel  \
# 0      18.0                         444
# 1      14.0                         346
# 2       0.0                           6
# 3      19.0                         406
# 4       0.0                         240
#
#    external_data_provider_credit_checks_last_month  \
# 0                                                2
# 1                                                1
# 2                                                2
# 3                                                3
# 4                                                2
#
#    external_data_provider_credit_checks_last_year  \
# 0                                               0
# 1                                               0
# 2                                               1
# 3                                               1
# 4                                               1
#
#    external_data_provider_email_seen_before  \
# 0                                      51.0
# 1                                      17.0
# 2                                       9.0
# 3                                      38.0
# 4                                      46.0
#
#    external_data_provider_fraud_score  reported_income  \
# 0                                 645          57849.0
# 1                                 243           4902.0
# 2                                  65         163679.0
# 3                                 815           1086.0
# 4                                 320         198618.0
#
#    score_1_1Rk8w4Ucd5yR3KcqZzLdow==  score_1_4DLlLW62jReXaqbPaHp1vQ==  \
# 0                              True                             False
# 1                             False                             False
# 2                             False                             False
# 3                              True                             False
# 4                             False                             False
#
#    score_1_8k8UDR4Yx0qasAjkGrUZLw==  score_1_DGCQep2AE5QRkNCshIAlFQ==  \
# 0                             False                             False
# 1                             False                              True
# 2                             False                              True
# 3                             False                             False
# 4                              True                             False
#
#    score_1_e4NYDor1NOw6XKGE60AWFw==  score_1_fyrlulOiZ+5hoFqLa6UbDQ==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_1_smzX0nxh5QlePvtVf6EAeg==  score_2_+2hzpeP1RWr8PEvL1WTUdw==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_+CxEO4w7jv3QPI/BQbyqAA==  score_2_/tdlnWjXoZ3OjdtBXzdOJQ==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                              True                             False
#
#    score_2_5/uMrqKj3OL/Xk5OrGx9fg==  score_2_55UK234RR1d7HIWJjmq9tw==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_6J1ZMTzN5GKHXnhM4J1JbA==  score_2_7h+tk4z7O9brtBSe1rNjxA==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_7h8PTkrlTWUPP3yuyP4rUg==  score_2_A+QuW1n/ABeiVVe/9CRZ9Q==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_Fv28Bz0YRTVAT5kl1bAV6g==  score_2_IOVu8au3ISbo6+zmfnYwMg==  \
# 0                             False                              True
# 1                             False                             False
# 2                              True                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_LCak332j+TYFqHC3NDwiqg==  score_2_NLvAOzzmJba/0zolQnWF5Q==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_O4i7FxcROACMVTCgI0WXuA==  score_2_OlDYtdljgSSYM/M1L2CRaQ==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_RO7MTL+j4PH2gNzbhNTq/A==  score_2_SaamrHMo23l/3TwXOWgVzw==  \
# 0                             False                             False
# 1                             False                              True
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_YLGMUI9hObSh6wD/xfanGg==  score_2_bopP0NxW3+r8tn9xIHTaOw==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_cdpgyOyZS04uXerMNu7uCw==  score_2_d/7Hedyz7ovK9Pn1CYN4+A==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_dCm9hFKfdRm7ej3jW+gyxw==  score_2_dWJRASUFMejk3AHZ1p1Gkg==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                              True                             False
# 4                             False                             False
#
#    score_2_emS9xH8CLoRNie2uSmaDAQ==  score_2_ky19q4V1ZqgL3jnHX0wKDw==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_mX2VRRG38RPiHX+MfjefRw==  score_2_osCzpM4hJrxugqWWuZmMWw==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_pAzpxkhjPsjWldgSX21+zg==  score_2_rJZgTmANW3PjOCQLCcp4iQ==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_tHpS8e9F8d9zg3iOQM9tsA==  score_2_tQUTfUyeuGkhRotd+6WjVg==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_vJyc9xom9v7hwFMPTIpmKw==  score_2_w1miZqhB5+RSamEQJa0rqg==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    score_2_wjdj2vxjWoDsEIk0l09ynw==  score_2_wkeCdGeu5sEv4/fjwR0aDg==  \
# 0                             False                             False
# 1                             False                             False
# 2                             False                             False
# 3                             False                             False
# 4                             False                             False
#
#    state_/+QaZYcpPt5mXLpkv6I8Bw==  state_/78Q+NAqnsdbiE2JReYK9Q==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_/EoxQEzy1PWWTtv6DNwr2w==  state_/L8vvVesB5WyAv190Hw/rQ==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_0gQEZgRHqS5KSF3oWQrQfw==  state_0lQuvmygO68ZFXZjzHEOww==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_1DpYl6dtzY0qE33poow3iw==  state_1tPrGp5Yx4Yev8EWxfJw2w==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_1vMmtGURgMcjxQbV2KQiUw==  state_1xxlFOWSFxK0/J2VdCKP3g==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_5hPtRY8gW/3+fPXvGIgWTg==  state_7bX4XFXmYqoMspxup0CrKA==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_82aTqSzrTImY+SbAOBQzGQ==  state_8ZKN5LHxobLWh6drCDlmhQ==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_9PWmQ/Uv20r8XvcwDXWUSw==  state_9sS116y/1CqWLVJ8nFOGZg==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_BB/zpwTH+8GCIVHlhzOU1Q==  state_DLK5rpOxZhCM5oQvfUpkTQ==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_E8shyM/6btBNXXExsO17zw==  state_GFOaXqGcKJxSSF9aBDDNaA==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_GW2VZ3dN3OGHSjQ6JkfqQw==  state_Jc0dzuliQSKFl0Xy0bjYCQ==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_JrdZzPZEa/YIIGwh8OdTKA==  state_KET/Pmr6rHp1RJ/P9ymztw==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                            True
# 4                           False                           False
#
#    state_LXZkF0tV1Ma9JIlIvaUDiw==  state_NX0S6z5x5fEStwXfBQN5FQ==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_OCoEDgPLpDjHcbEmPpAjvA==  state_P1TKs1aii8osbgO+MszZ2w==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_QCVqG0wT4xPLQuiTIExO2w==  state_QMl/wADluYmoYZIXDOUktQ==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_TYC58USu+Tq7c/WS4YLnuQ==  state_VafbDA6D5W2TpGMAUJbW8Q==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_Ygq6MsM98oC8yceExr69Ig==  state_ZUmHOp1/xBWh5O/uqDutsw==  \
# 0                           False                           False
# 1                           False                           False
# 2                            True                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_ZVfsutsd1Go0zZEnGp0vEA==  state_bNDXnbe7XAx/VUe+cbjDiw==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_bwNrC22VlFOFk6/nEHQc6A==  state_cd+7k16vaf6SzwSyvT/fHw==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_fMOpZ7DFhwQgTxW547UMCQ==  state_fR2lwAMjCb/fNXjsApiOTw==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_kfFcVGcsJmH2n3eYprLkeQ==  state_orU7WJYGPT/xFwOXY1eBkw==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_qItmSqWrjm+MopDA+UpKRw==  state_rrVbgRNTRyB6auEycsRrpA==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_sjJbkqJS7cXalHLBFA+EOQ==  state_umkEte5GXWggFkMOtKQ3Ug==  \
# 0                            True                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    state_x6Gw/1I8t3KPgT6s82Kodg==  state_xsd3ZdsI3356I3xMxZeiqQ==  \
# 0                           False                           False
# 1                           False                            True
# 2                           False                           False
# 3                           False                           False
# 4                           False                            True
#
#    state_ygE7OTdsxRMLeXMa0EZwZw==  state_yni6lL4oSly97UVZeRSyxA==  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#    real_state_+qWF9pJpVGtTFn4vFjb/cg==  real_state_N5/CE7lSkAfB04hVFFwllw==  \
# 0                                False                                 True
# 1                                False                                 True
# 2                                False                                False
# 3                                False                                False
# 4                                False                                False
#
#    real_state_UX7AdFYgQh+VrVC5eIaU9w==  real_state_n+xK9CfX0bCn77lClTWviw==  \
# 0                                False                                False
# 1                                False                                False
# 2                                False                                 True
# 3                                False                                 True
# 4                                False                                 True
#
#    real_state_nSpvDsIsslUaX6GE6m6eQA==  shipping_state_BR-AC  \
# 0                                False                 False
# 1                                False                 False
# 2                                False                 False
# 3                                False                 False
# 4                                False                 False
#
#    shipping_state_BR-AL  shipping_state_BR-AM  shipping_state_BR-AP  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    shipping_state_BR-BA  shipping_state_BR-CE  shipping_state_BR-DF  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    shipping_state_BR-ES  shipping_state_BR-GO  shipping_state_BR-MA  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    shipping_state_BR-MG  shipping_state_BR-MS  shipping_state_BR-MT  \
# 0                 False                 False                  True
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                  True
#
#    shipping_state_BR-PA  shipping_state_BR-PB  shipping_state_BR-PE  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    shipping_state_BR-PR  shipping_state_BR-RN  shipping_state_BR-RO  \
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                  True                 False
# 4                 False                 False                 False
#
#    shipping_state_BR-RR  shipping_state_BR-RS  shipping_state_BR-SC  \
# 0                 False                 False                 False
# 1                 False                  True                 False
# 2                  True                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False
#
#    shipping_state_BR-SE  shipping_state_BR-SP  shipping_state_BR-TO
# 0                 False                 False                 False
# 1                 False                 False                 False
# 2                 False                 False                 False
# 3                 False                 False                 False
# 4                 False                 False                 False

# %%
## Training the model

# feature matrix
X = df_dataset_encoded.drop('target_default', axis=1)

# target vector
y = df_dataset_encoded['target_default']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, shuffle=True, stratify=y, test_size=0.20, random_state=25
)

X_dev, X_val, y_dev, y_val = train_test_split(
    X_train, y_train, shuffle=True, stratify=y_train, test_size=0.3, random_state=25
)

# %%
X_dev.shape, X_val.shape, X_test.shape
# Out:
# ((23374, 143), (10018, 143), (8349, 143))

# %%
# ---- Reconstruct dataframes with target ----
dev_df = X_dev.copy()
dev_df['target_default'] = y_dev
dev_df['Sampling'] = 'DEV'

val_df = X_val.copy()
val_df['target_default'] = y_val
val_df['Sampling'] = 'VAL'

test_df = X_test.copy()
test_df['target_default'] = y_test
test_df['Sampling'] = 'TEST'

# ---- Combine all splits ----
final_df = pd.concat([dev_df, val_df, test_df], axis=0)

# Optional: reset index
final_df = final_df.reset_index(drop=True)

# ---- Save to CSV ----
final_df.to_csv('model_dataset_with_sampling.csv', index=False)
